# %% [markdown]
# # TISSUE differential gene expression analysis
#
# This notebook contains code for analyzing and plotting the TISSUE differential gene expression results obtained from all imputation experiments using the `get_external_multi_ttest.py` script. The analysis is done at whole-transcriptome level to provide unbiased characterization of differential expression of imputed genes. The comparisons are done for Near vs Far target cells with respect to NSC/T cells and for NSC/T cells that are stronger or weaker in their effects. We perform pathway enrichment for GO biological process using GSEAPy.

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import squidpy as sq
import anndata as ad
from scipy.stats import pearsonr, spearmanr
import pickle
import os
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
from matplotlib.collections import PatchCollection
from matplotlib.colors import ListedColormap
import seaborn as sns
sns.set_style("ticks")
from sklearn.neighbors import BallTree
import gseapy as gp

from scipy.stats import mannwhitneyu, ttest_ind
from decimal import Decimal

from statsmodels.stats.multitest import multipletests
import gseapy as gp

os.chdir("/labs/abrunet1/Eric/MERFISH")

from ageaccel_proximity import *
from clock_preprocessing import *

# %%
# from TISSUE package

def large_load(dirpath, skipfiles=[]):
    '''
    Loads in anndata and associated pandas dataframe csv files to be added to obsm metadata and uns metadata.
    Input is the directory path to the output directory of large_save()
    
    Parameters
    ----------
        dirpath [str] - path to directory for where outputs of large_save() are located
        skipfiles [list] - list of filenames to exclude from anndata object
    
    Returns
    -------
        adata - AnnData object loaded from dirpath along with all obsm and uns key values added to metadata
    '''
    # read h5ad anndata object
    adata = ad.read_h5ad(os.path.join(dirpath, "adata.h5ad"))
    
    # read and load in obsm from CSV files
    for fn in os.listdir(dirpath):
        if (".csv" in fn) and (fn not in skipfiles):
            df = pd.read_csv(os.path.join(dirpath, fn))
            df.index = adata.obs_names
            key = fn.split(".")[0]
            adata.obsm[key] = df
            
    # read and load any usn metadata from CSV files
    if os.path.isdir(os.path.join(dirpath,"uns")):
        for fn in os.listdir(os.path.join(dirpath,"uns")):
            if (".csv" in fn) and (fn not in skipfiles):
                df = pd.read_csv(os.path.join(dirpath,"uns",fn))
                key = fn.split(".")[0]
                adata.uns[key] = df
            
    return(adata)

# %% [markdown]
# ## TISSUE DGEA for all Near vs Far and Strong vs Weak comparisons

# %% [markdown]
# ### T cell (Near vs Far)
#
# Target cells near T cells compared to Target cells far from T cells

# %%
# read in results

adata = large_load("results/for_imputation/SCPI_k4_k1/SVZ_spage_tangram_MI_EXTERNAL_TTEST_proximity to T cell_Near",
                   skipfiles=["tangram_predicted_expression.csv",
                              "tangram_predicted_expression_groups.csv",
                              "tangram_predicted_expression_uncertainty.csv",
                              "spage_predicted_expression.csv",
                              "spage_predicted_expression_groups.csv",
                              "spage_predicted_expression_uncertainty.csv",
                              "knn_predicted_expression.csv",
                              "knn_predicted_expression_groups.csv",
                              "knn_predicted_expression_uncertainty.csv",])

# %%
# get dataframe with p-values and t-statistics

df = adata.uns["spage_Near_Far_pvalue"].T
df.columns = ["SpaGE p"]
df["Tangram p"] = adata.uns["tangram_Near_Far_pvalue"].T

df["SpaGE t"] = adata.uns["spage_Near_Far_tstat"].T
df["Tangram t"] = adata.uns["tangram_Near_Far_tstat"].T

df.sort_values("SpaGE p")
# Out:
#                     SpaGE p     Tangram p   SpaGE t  Tangram t
# ifit3          1.431619e-10  4.987477e-11  6.431408   6.591988
# ifit3b         4.400597e-08  4.779302e-05  5.496116   4.085462
# oasl2          2.297273e-07  2.445897e-07  5.201740   5.181364
# isg15          8.236299e-07  4.455670e-09  4.932650   5.869737
# stat1          2.595776e-06  3.562040e-12  4.719425   6.980865
# ...                     ...           ...       ...        ...
# bcl11a         9.998056e-01  5.226500e-01  0.000244   0.639448
# zfp141         9.998408e-01  9.805397e-02 -0.000200   1.658107
# cr2            9.999288e-01  4.235992e-01  0.000089   0.801183
# tex9           9.999916e-01  1.303424e-01 -0.000011   1.514007
# 4933427d14rik  9.999941e-01  2.425571e-01 -0.000007   1.170268
#
# [12719 rows x 4 columns]

# %%
# get lists of DEGs

# # p-value selection (permissive)
rejected = (df['SpaGE p']<0.05)&(df['Tangram p']<0.05)

# remove conflicting directions
rejected[(np.sign(df['SpaGE t'])!=np.sign(df['Tangram t']))] = False

# print DEGs
print("UP:")
sig_genes_up = df.index.values[rejected & (df['SpaGE t'].values>0)]
sig_genes_up = [x.capitalize() for x in sig_genes_up]
for gene in sig_genes_up:
    print(gene)

print("\nDOWN:")
sig_genes_down = df.index.values[rejected & (df['SpaGE t'].values<0)]
sig_genes_down = [x.capitalize() for x in sig_genes_down]
for gene in sig_genes_down:
    print(gene)
# Out:
# UP:
# Cflar
# Acadl
# Dnpep
# Sp100
# Itm2c
# Nifk
# Dars
# Tor3a
# Tmco1
# Atf3
# Phyh
# Mllt10
# Abi1
# Lrrc8a
# Ass1
# Nmi
# Ifih1
# Nfe2l2
# Pygb
# Cebpb
# Cetn2
# Idh3g
# Diaph2
# Anxa5
# Lxn
# Kpna4
# Pbxip1
# Mcl1
# Notch2
# Csf1
# Camk2d
# Gbp7
# Gbp3
# Gbp2
# Asph
# Plekhf2
# Gem
# Ddx58
# Il11ra1
# Stoml2
# Nadk
# Isg15
# Rheb
# Hopx
# Naaa
# Cxcl10
# Fbrsl1
# Ttc28
# Oasl2
# Aldh2
# Samd9l
# Zc3hav1
# Parp12
# Herc6
# Pole4
# Usp18
# Lpcat3
# Tpi1
# Tnfrsf1a
# Mrps35
# Napa
# Clptm1
# Fxyd1
# Gpi1
# Ppp1r15a
# Ldha
# Idh2
# Trim34a
# Trim12a
# Trim12c
# Trim30a
# Trim30d
# Oat
# Rnh1
# Irf7
# Ginm1
# Chchd10
# Pfkl
# Stat2
# Cpe
# Sin3b
# Calr
# Junb
# Mt3
# Psmb10
# Anxa7
# Glud1
# Ghitm
# Pnp
# Tox4
# Psme1
# Emc9
# Psme2
# Irf9
# Dhrs1
# Zmym5
# Phf11d
# Icam1
# Usp2
# Pkm
# Tmod3
# Gclc
# Xrn1
# Nck1
# Lamb2
# Shisa5
# Irgm1
# 9930111j21rik2
# Ifi47
# Irf1
# Pdlim4
# Igtp
# Spag7
# Xaf1
# Lgals9
# Wsb1
# Slfn2
# Ddx52
# Cdk5rap3
# Ifi35
# Pitpnc1
# Gna13
# Lgals3bp
# Gaa
# Rnf213
# Abt1
# Gcnt2
# Sfxn1
# Srek1ip1
# Laptm4a
# Rsad2
# Cmpk2
# Nampt
# Srsf5
# Aldh6a1
# Ifi27l2a
# Serpina3n
# Rapgef5
# Vps28
# Apobec3
# Cyb5r3
# Tspo
# Mlc1
# Prr13
# Cluap1
# Cebpd
# Rtp4
# Parp14
# Parp9
# Pros1
# Usp25
# Lnpep
# Zfand3
# Cbs
# Tapbp
# Psmb9
# Tap1
# Psmb8
# Tap2
# H2-q4
# Flot1
# Ppp1r10
# H2-t23
# H2-t22
# Eif2ak2
# Hsd17b4
# Aldh7a1
# Gm4951
# Iigp1
# Coro1b
# Ccs
# Ifit2
# Ifit3
# Ifit3b
# Pgam1
# Eif3a
# Stat3
# H2-k1
# Clu
# Gapdh
# Bst2
# Ifi27
# C4b
# Ifit1
# Jak1
# S100a6
# H2-d1
# Ifitm3
# Slc1a3
# Stat1
#
# DOWN:

# %%
cutoff = 0.1


# UP
enr_up = gp.enrichr(gene_list=list(sig_genes_up),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             outdir=f"results/for_imputation/pathway_enrichment/NvF_Tcell_up",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_up.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=5,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()

# DOWN
enr_down = gp.enrichr(gene_list=list(sig_genes_down),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             outdir=f"results/for_imputation/pathway_enrichment/NvF_Tcell_down",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_down.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=5,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()
# Out:
# 2023-11-26 17:46:54,370 [INFO] Run: GO_Biological_Process_2023
# 2023-11-26 17:46:55,874 [INFO] Save enrichment results for GO_Biological_Process_2023
# 2023-11-26 17:46:57,200 [INFO] Done.
# 2023-11-26 17:46:58,068 [INFO] Run: GO_Biological_Process_2023
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[10], line 26
#      23 plt.show()
#      25 # DOWN
# ---> 26 enr_down = gp.enrichr(gene_list=list(sig_genes_down),
#      27              gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
#      28              background=[x.capitalize() for x in df.index.values],
#      29              organism="mouse",
#      30              outdir=f"results/for_imputation/pathway_enrichment/NvF_Tcell_down",
#      31              verbose=True,
#      32              cutoff=cutoff)
#      34 ax = gp.dotplot(enr_down.results,
#      35           column="Adjusted P-value",
#      36           x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
#    (...)
#      42           cutoff = cutoff
#      43          )
#      44 plt.show()
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/__init__.py:510, in enrichr(gene_list, gene_sets, organism, outdir, background, cutoff, format, figsize, top_term, no_plot, verbose)
#     508 # set organism
#     509 enr.set_organism()
# --> 510 enr.run()
#     512 return enr
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:506, in Enrichr.run(self)
#     504     self._logger.debug("Enrichr service using library: %s" % (self._gs))
#     505     # self._logger.info("Enrichr Library: %s"% self._gs)
# --> 506     shortID, res = self.get_results(genes_list)
#     507     # Remember gene set library used
#     508 res.insert(0, "Gene_set", self._gs)
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:230, in Enrichr.get_results(self, gene_list)
#     228 """Enrichr API"""
#     229 ADDLIST_URL = "%s/%s/addList" % (self.ENRICHR_URL, self._organism)
# --> 230 job_id = self.send_genes(gene_list, ADDLIST_URL)
#     231 user_list_id = job_id["userListId"]
#     233 RESULTS_URL = "%s/%s/export" % (self.ENRICHR_URL, self._organism)
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:205, in Enrichr.send_genes(self, gene_list, url)
#     203     self._logger.debug(url)
#     204     self._logger.debug(payload)
# --> 205     raise Exception("Error sending gene list, try again later")
#     206 job_id = json.loads(response.text)
#     208 return job_id
#
# Exception: Error sending gene list, try again later

# %%
# concat results
enr_up.res2d['UP_DW'] = "UP"

enr_up_new = enr_up
enr_up_new.results["Term"] = [v.split("(GO:")[0] for v in enr_up_new.results["Term"].values]

ax = gp.barplot(enr_up_new.results,
                top_term=5,
                cutoff=0.05,
                title='GO BP',
                figsize=(1.5,4),
                color='salmon')
plt.tight_layout()
plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_Tcell_up.pdf",
           bbox_inches='tight')
plt.show()
# Out:
# /local/scratch/edsun/slrmtmp.42177532/ipykernel_26828/563887598.py:13: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### T cell (Strong vs Weak)
#
# T cells with more pro-aging effects compared to T cells with less pro-aging effects

# %%
adata = large_load("results/for_imputation/SCPI_k4_k1/SVZDulken_spage_tangram_MI_EXTERNAL_TTEST_T cell_neighborhood_type_Strong",
                   skipfiles=["tangram_predicted_expression.csv",
                              "tangram_predicted_expression_groups.csv",
                              "tangram_predicted_expression_uncertainty.csv",
                              "spage_predicted_expression.csv",
                              "spage_predicted_expression_groups.csv",
                              "spage_predicted_expression_uncertainty.csv",
                              "knn_predicted_expression.csv",
                              "knn_predicted_expression_groups.csv",
                              "knn_predicted_expression_uncertainty.csv",])

# %%
# get dataframe with p-values and t-statistics

df = adata.uns["spage_Strong_Weak_pvalue"].T
df.columns = ["SpaGE p"]
df["Tangram p"] = adata.uns["tangram_Strong_Weak_pvalue"].T

df["SpaGE t"] = adata.uns["spage_Strong_Weak_tstat"].T
df["Tangram t"] = adata.uns["tangram_Strong_Weak_tstat"].T

df.sort_values("SpaGE p")
# Out:
#                 SpaGE p  Tangram p   SpaGE t  Tangram t
# rpl29          0.000617   0.108842  3.424609   1.603426
# rpl27a         0.000667   0.103776  3.403364   1.626820
# rps21          0.000738   0.084664  3.375287   1.724247
# rps13          0.000963   0.060242  3.301277   1.879020
# rpl36a         0.001149   0.049797  3.251491   1.961708
# ...                 ...        ...       ...        ...
# tada1          0.999537   0.820604 -0.000580   0.226814
# cfap74         0.999552   0.953477  0.000562   0.058383
# a830010m20rik  0.999662   0.959311 -0.000424   0.051055
# srgap3         0.999892   0.906567 -0.000136  -0.117419
# 9130023h24rik  0.999999   0.847340  0.000001  -0.192658
#
# [8170 rows x 4 columns]

# %%
# get lists of DEGs

# # p-value selection (permissive)
rejected = (df['SpaGE p']<0.05)&(df['Tangram p']<0.05)

# remove conflicting directions
rejected[(np.sign(df['SpaGE t'])!=np.sign(df['Tangram t']))] = False

# print DEGs
print("UP:")
sig_genes_up = df.index.values[rejected & (df['SpaGE t'].values>0)]
sig_genes_up = [x.capitalize() for x in sig_genes_up]
for gene in sig_genes_up:
    print(gene)

print("\nDOWN:")
sig_genes_down = df.index.values[rejected & (df['SpaGE t'].values<0)]
sig_genes_down = [x.capitalize() for x in sig_genes_down]
for gene in sig_genes_down:
    print(gene)
# Out:
# UP:
# Ptpn18
# Stk17b
# Sp110
# Bcl2
# Rgs1
# Cd48
# Gm4955
# Pyhin1
# Mndal
# Traf1
# Dusp2
# Zbp1
# Il2rg
# Rpl36a
# Mbnl1
# Fam189b
# S100a4
# S100a10
# Cd2
# Ptpn22
# Gm12840
# Lck
# Fgl2
# Gimap4
# Gimap3
# Gm9844
# Rinl
# Hcst
# Cd37
# Emp3
# Isg20
# Coro1a
# Sept1
# Lsp1
# B4galnt1
# Rps18-ps3
# Cotl1
# Rpl13-ps3
# Lcp1
# Epsti1
# Thy1
# Cd3d
# Shisa5
# Rpsa
# Cd27
# Cd52
# Nkg7
# Cd3g
# Lat
# Ptprc
# Cd8b1
# Cd8a
#
# DOWN:

# %%
cutoff = 0.1


# UP
enr_up = gp.enrichr(gene_list=list(sig_genes_up),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             outdir=f"results/for_imputation/pathway_enrichment/SvW_Tcell_up",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_up.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=5,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()

# DOWN
enr_down = gp.enrichr(gene_list=list(sig_genes_down),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             outdir=f"results/for_imputation/pathway_enrichment/SvW_Tcell_down",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_down.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=5,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()
# Out:
# 2023-11-07 15:45:26,191 [INFO] Run: GO_Biological_Process_2023
# 2023-11-07 15:45:27,251 [INFO] Save enrichment results for GO_Biological_Process_2023
# 2023-11-07 15:45:27,695 [INFO] Done.
# 2023-11-07 15:45:28,451 [INFO] Run: GO_Biological_Process_2023
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[15], line 26
#      23 plt.show()
#      25 # DOWN
# ---> 26 enr_down = gp.enrichr(gene_list=list(sig_genes_down),
#      27              gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
#      28              background=[x.capitalize() for x in df.index.values],
#      29              organism="mouse",
#      30              outdir=f"results/for_imputation/pathway_enrichment/SvW_Tcell_down",
#      31              verbose=True,
#      32              cutoff=cutoff)
#      34 ax = gp.dotplot(enr_down.results,
#      35           column="Adjusted P-value",
#      36           x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
#    (...)
#      42           cutoff = cutoff
#      43          )
#      44 plt.show()
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/__init__.py:510, in enrichr(gene_list, gene_sets, organism, outdir, background, cutoff, format, figsize, top_term, no_plot, verbose)
#     508 # set organism
#     509 enr.set_organism()
# --> 510 enr.run()
#     512 return enr
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:506, in Enrichr.run(self)
#     504     self._logger.debug("Enrichr service using library: %s" % (self._gs))
#     505     # self._logger.info("Enrichr Library: %s"% self._gs)
# --> 506     shortID, res = self.get_results(genes_list)
#     507     # Remember gene set library used
#     508 res.insert(0, "Gene_set", self._gs)
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:230, in Enrichr.get_results(self, gene_list)
#     228 """Enrichr API"""
#     229 ADDLIST_URL = "%s/%s/addList" % (self.ENRICHR_URL, self._organism)
# --> 230 job_id = self.send_genes(gene_list, ADDLIST_URL)
#     231 user_list_id = job_id["userListId"]
#     233 RESULTS_URL = "%s/%s/export" % (self.ENRICHR_URL, self._organism)
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:205, in Enrichr.send_genes(self, gene_list, url)
#     203     self._logger.debug(url)
#     204     self._logger.debug(payload)
# --> 205     raise Exception("Error sending gene list, try again later")
#     206 job_id = json.loads(response.text)
#     208 return job_id
#
# Exception: Error sending gene list, try again later

# %%
# concat results
enr_up.res2d['UP_DW'] = "UP"

enr_up_new = enr_up
enr_up_new.results["Term"] = [v.split("(GO:")[0] for v in enr_up_new.results["Term"].values]

ax = gp.barplot(enr_up_new.results,
                top_term=5,
                cutoff=0.05,
                title='GO BP',
                figsize=(1.5,4),
                color='salmon')
plt.tight_layout()
plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_SvW_Tcell_up.pdf",
           bbox_inches='tight')
plt.show()
# Out:
# /local/scratch/edsun/slrmtmp.42103730/ipykernel_6192/2557701524.py:13: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### NSC (Near vs Far)
#
# Target cells near NSCs compared to Target cells far from NSCs

# %%
# read in results

adata = large_load("results/for_imputation/SCPI_k4_k1/SVZ_spage_tangram_MI_EXTERNAL_TTEST_proximity to NSC_Near",
                   skipfiles=["tangram_predicted_expression.csv",
                              "tangram_predicted_expression_groups.csv",
                              "tangram_predicted_expression_uncertainty.csv",
                              "spage_predicted_expression.csv",
                              "spage_predicted_expression_groups.csv",
                              "spage_predicted_expression_uncertainty.csv",
                              "knn_predicted_expression.csv",
                              "knn_predicted_expression_groups.csv",
                              "knn_predicted_expression_uncertainty.csv",])

# %%
# get dataframe with p-values and t-statistics

df = adata.uns["spage_Near_Far_pvalue"].T
df.columns = ["SpaGE p"]
df["Tangram p"] = adata.uns["tangram_Near_Far_pvalue"].T

df["SpaGE t"] = adata.uns["spage_Near_Far_tstat"].T
df["Tangram t"] = adata.uns["tangram_Near_Far_tstat"].T

df.sort_values("SpaGE p")
# Out:
#                 SpaGE p     Tangram p   SpaGE t  Tangram t
# mt-nd2         0.000000  0.000000e+00 -9.035457  23.856141
# mt-nd1         0.000000  0.000000e+00 -8.562601  24.180762
# gm10561        0.000000  0.000000e+00  9.020152  14.613717
# tcf7l2         0.000000  0.000000e+00  8.575409  15.064907
# notch2         0.000000  0.000000e+00  8.535591  13.856352
# ...                 ...           ...       ...        ...
# stc1           0.999586  1.028663e-05 -0.000519   4.471105
# dhx58          0.999756  1.469393e-02 -0.000306   2.451329
# fam241a        0.999854  1.070888e-07 -0.000182   5.348858
# d930030i03rik  0.999957  9.227382e-03 -0.000055   2.614973
# slc46a2        0.999998  9.639409e-02 -0.000003   1.666297
#
# [12719 rows x 4 columns]

# %%
# get lists of DEGs

# # p-value selection (permissive)
rejected = (df['SpaGE p']<0.05)&(df['Tangram p']<0.05)

# remove conflicting directions
rejected[(np.sign(df['SpaGE t'])!=np.sign(df['Tangram t']))] = False

# print DEGs
print("UP:")
sig_genes_up = df.index.values[rejected & (df['SpaGE t'].values>0)]
sig_genes_up = [x.capitalize() for x in sig_genes_up]
for gene in sig_genes_up:
    print(gene)
# Out:
# UP:
# Lypla1
# Tcea1
# Rgs20
# Rb1cc1
# 4732440d04rik
# Rrs1
# Adhfe1
# Vcpip1
# Sgk3
# Prex2
# Tram1
# Lactb2
# Eloc
# Tmem70
# Paqr8
# Tmem14a
# B3gat2
# Smap1
# Fam135a
# Imp4
# Fam168b
# Plekhb2
# Uggt1
# Lman2l
# Cnnm3
# Coa5
# Unc50
# Pantr1
# Pou3f3
# Col5a2
# Slc39a10
# Inpp1
# Hibch
# Osgepl1
# Asnsd1
# Stk17b
# Coq10b
# Mob4
# Rftn2
# Gm10561
# Maip1
# Ndufb3
# Cflar
# Fzd7
# Nbeal1
# Raph1
# Gm20342
# Adam23
# Creb1
# Fzd5
# Plekhm3
# Idh1
# Acadl
# Atic
# Igfbp5
# Arpc2
# Usp37
# Plcd4
# Stk16
# Tuba4a
# Dnpep
# Acsl3
# Utp14b
# Serpine2
# Mff
# Pid1
# Trip12
# Itm2c
# 2810459m11rik
# Psmd1
# Ecel1
# Prss56
# Gigyf2
# Ngef
# Dgkd
# Usp40
# Arl4c
# Hes6
# Ndufa10
# Stk25
# Ing5
# Gin1
# Pam
# 2310035c23rik
# Bcl2
# Kdsr
# Epb41l5
# Steap3
# Nckap5
# Mgat5
# Rab3gap1
# R3hdm1
# Ubxn4
# Dars
# Elk4
# Mdm4
# Ppp1r15b
# Tmem183a
# Arl8a
# Gpr37l1
# Rnpep
# Timm17a
# Tmem9
# Zbtb41
# Cdc73
# B3galt2
# Trove2
# Rnf2
# Tsen15
# Rgl1
# Ier5
# Xpr1
# Cep350
# Tor1aip1
# Tor1aip2
# Soat1
# Ralgps2
# Mrps14
# Prdx6
# Prrc2c
# Fmo1
# Prrx1
# Gm26523
# Trmt112
# Fkbp2
# Flrt1
# Slc3a2
# Polr2g
# Ttc9c
# Uqcc3
# B3gat3
# Asrgl1
# Fads1
# Ddb1
# Mrpl16
# Zfp91
# Tle4
# Gnaq
# Vps13a
# Carnmt1
# Rorb
# Trpm3
# Plgrkt
# Ric1
# 9930021j03rik
# Uhrf2
# Gldc
# Cstf2t
# Papss2
# Pten
# Ifit2
# Ifit3
# Ifit3b
# Pank1
# Pcgf5
# Fgfbp3
# Btaf1
# Ide
# Tbc1d12
# Sorbs1
# Pgam1
# Zdhhc16
# Zfyve27
# Cutc
# Nolc1
# Cuedc2
# Trim8
# Arl3
# Sfxn2
# Borcs7
# As3mt
# Xpnpep1
# Add3
# Smndc1
# Gpam
# Zdhhc6
# Tcf7l2
# Ccdc186
# Trub1
# Gfra1
# Pdzd8
# Emx2os
# Emx2
# Fam204a
# Eif3a
# Fam45a
# Prdx3
# Zfp950
# Csf2ra
# Crym
# Ercc1
# Ogt
# Pdpn
# B2m
# Stat3
# H2-k1
# Atp1a2
# Ppargc1a
# Gapdh
# Thbs4
# Sirt7
# Bst2
# Gja1
# Srebf1
# Slc1a2
# Echdc1
# Hes5
# C4b
# Insr
# Ifit1
# Fads2
# Mboat2
# Fxn
# Jak1
# S100a6
# Efnb2
# H2-d1
# Sox9
# Aldoc
# Socs3
# C1ql3
# Alcam
# Fgfr3
# Rims2
# Pisd
# Slc1a3
# Vcam1
# Il10rb
# Apoe
# Aldh1l1
# Nr2e1
# Vegfa
# Sox2
# Msmo1
# Btg2
# Grn
# Tox
# Ccl4
# Nfkb1
# Cat
# Gstm1
# Ptprz1
# Stat1
# Gfap
# Lsamp

# %%
print("\nDOWN:")
sig_genes_down = df.index.values[rejected & (df['SpaGE t'].values<0)]
sig_genes_down = [x.capitalize() for x in sig_genes_down]
for gene in sig_genes_down:
    print(gene)
# Out:
# DOWN:
# Nkx2-9
# Tmem117
# Serpind1

# %%
cutoff = 0.1


# UP
enr_up = gp.enrichr(gene_list=list(sig_genes_up),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             outdir=f"results/for_imputation/pathway_enrichment/NvF_NSC_up",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_up.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=10,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()

# DOWN
enr_down = gp.enrichr(gene_list=list(sig_genes_down),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             outdir=f"results/for_imputation/pathway_enrichment/NvF_NSC_down",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_down.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=10,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()
# Out:
# 2023-11-07 15:37:32,799 [INFO] Run: GO_Biological_Process_2023
# 2023-11-07 15:37:39,165 [INFO] Save enrichment results for GO_Biological_Process_2023
# 2023-11-07 15:37:39,538 [INFO] Done.
# 2023-11-07 15:37:40,399 [INFO] Run: GO_Biological_Process_2023
# 2023-11-07 15:37:41,213 [INFO] Save enrichment results for GO_Biological_Process_2023
# 2023-11-07 15:37:41,607 [INFO] Done.

# %%
# concat results
enr_up.res2d['UP_DW'] = "UP"
enr_down.res2d['UP_DW'] = "DOWN"
enr_res = pd.concat([enr_up.res2d.head(), enr_down.res2d.head()])


ax = gp.barplot(enr_res,
                top_term=5,
                cutoff=0.05,
                title='GO BP',
                group ='UP_DW',
                color = ['cornflowerblue','salmon'],
                figsize=(2,5))
plt.show()

# %%
# concat results
enr_up.res2d['UP_DW'] = "UP"

enr_up_new = enr_up
enr_up_new.results["Term"] = [v.split("(GO:")[0] for v in enr_up_new.results["Term"].values]

ax = gp.barplot(enr_up_new.results,
                top_term=5,
                cutoff=0.05,
                title='GO BP',
                figsize=(1.5,4),
                color='cornflowerblue')
plt.tight_layout()
plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_NSC_up.pdf",
           bbox_inches='tight')
plt.show()


# concat results
enr_down.res2d['UP_DW'] = "DOWN"

enr_down_new = enr_down
enr_down_new.results["Term"] = [v.split("(GO:")[0] for v in enr_down_new.results["Term"].values]

ax = gp.barplot(enr_down_new.results,
                top_term=5,
                cutoff=0.05,
                title='GO BP',
                figsize=(1.5,4),
                color='cornflowerblue')
plt.tight_layout()
plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_NSC_down.pdf",
           bbox_inches='tight')
plt.show()
# Out:
# /local/scratch/edsun/slrmtmp.42103730/ipykernel_4567/596169442.py:13: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /local/scratch/edsun/slrmtmp.42103730/ipykernel_4567/596169442.py:31: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### NSC (Strong vs Weak)
#
# NSCs with more pro-rejuvenating effects compared to NSCs with less pro-rejuvenating effects

# %%
# read in results

adata = large_load("results/for_imputation/SCPI_k4_k1/SVZ_spage_tangram_MI_EXTERNAL_TTEST_NSC_neighborhood_type_Strong",
                   skipfiles=["tangram_predicted_expression.csv",
                              "tangram_predicted_expression_groups.csv",
                              "tangram_predicted_expression_uncertainty.csv",
                              "spage_predicted_expression.csv",
                              "spage_predicted_expression_groups.csv",
                              "spage_predicted_expression_uncertainty.csv",
                              "knn_predicted_expression.csv",
                              "knn_predicted_expression_groups.csv",
                              "knn_predicted_expression_uncertainty.csv",])

# %%
# get dataframe with p-values and t-statistics

df = adata.uns["spage_Strong_Weak_pvalue"].T
df.columns = ["SpaGE p"]
df["Tangram p"] = adata.uns["tangram_Strong_Weak_pvalue"].T

df["SpaGE t"] = adata.uns["spage_Strong_Weak_tstat"].T
df["Tangram t"] = adata.uns["tangram_Strong_Weak_tstat"].T

df.sort_values("SpaGE p")
# Out:
#                 SpaGE p     Tangram p   SpaGE t  Tangram t
# fdps           0.000002  1.110223e-15  4.773689   8.084252
# dclk2          0.000046  0.000000e+00  4.080368   9.964569
# fdft1          0.000088  0.000000e+00  3.939872  10.058477
# hmgcs1         0.000093  1.176836e-14  3.919364   7.766638
# rps27          0.000112  0.000000e+00 -3.865469   8.803879
# ...                 ...           ...       ...        ...
# tnni1          0.999615  2.274010e-01  0.000482   1.207571
# ctf1           0.999657  3.665280e-02 -0.000430   2.094740
# slc25a19       0.999692  1.562498e-07 -0.000386   5.292163
# lgals2         0.999799  8.506696e-01 -0.000252   0.188362
# 7630403g23rik  0.999939  4.731500e-01  0.000077   0.718020
#
# [12719 rows x 4 columns]

# %%
df.sort_values("SpaGE p")
# Out:
#                 SpaGE p     Tangram p   SpaGE t  Tangram t
# fdps           0.000002  1.110223e-15  4.773689   8.084252
# dclk2          0.000046  0.000000e+00  4.080368   9.964569
# fdft1          0.000088  0.000000e+00  3.939872  10.058477
# hmgcs1         0.000093  1.176836e-14  3.919364   7.766638
# rps27          0.000112  0.000000e+00 -3.865469   8.803879
# ...                 ...           ...       ...        ...
# tnni1          0.999615  2.274010e-01  0.000482   1.207571
# ctf1           0.999657  3.665280e-02 -0.000430   2.094740
# slc25a19       0.999692  1.562498e-07 -0.000386   5.292163
# lgals2         0.999799  8.506696e-01 -0.000252   0.188362
# 7630403g23rik  0.999939  4.731500e-01  0.000077   0.718020
#
# [12719 rows x 4 columns]

# %%
# get lists of DEGs

# # p-value selection (permissive)
rejected = (df['SpaGE p']<0.05)&(df['Tangram p']<0.05)

# remove conflicting directions
rejected[(np.sign(df['SpaGE t'])!=np.sign(df['Tangram t']))] = False

# print DEGs
print("UP:")
sig_genes_up = df.index.values[rejected & (df['SpaGE t'].values>0)]
sig_genes_up = [x.capitalize() for x in sig_genes_up]
for gene in sig_genes_up:
    print(gene)

print("\nDOWN:")
sig_genes_down = df.index.values[rejected & (df['SpaGE t'].values<0)]
sig_genes_down = [x.capitalize() for x in sig_genes_down]
for gene in sig_genes_down:
    print(gene)
# Out:
# UP:
# St18
# Mcm3
# Ptp4a1
# Zfp451
# Pantr1
# Pou3f3
# Myo1b
# Raph1
# Idh1
# Usp37
# Epha4
# Gpc1
# Mcm6
# Dars
# Tmem183a
# Glrx2
# Rgs16
# Pou2f1
# Ndufs2
# Usf1
# Pex19
# H3f3a
# Cdc123
# Vim
# Med22
# Psmb7
# Kif5c
# Rif1
# Arl6ip6
# Hat1
# Dlx1as
# Dlx2
# Cdca7
# Sp3
# Ola1
# Chn1
# Mtx2
# Mtch2
# Mdk
# Gm13889
# Api5
# Rad51
# Dut
# E2f1
# Pfdn4
# Nelfcd
# Prelid3b
# Lsm14b
# Adrm1
# Dnajc5
# Polr3k
# Plp2
# Rbm3
# Rbmx2
# Arx
# Pola1
# Apoo
# Maged1
# Nono
# Pou3f4
# Bhlhb9
# Impa1
# Actl6a
# Elf2
# Ufm1
# Commd2
# Pfn2
# Tsc22d2
# Dclk2
# Fdps
# Rnf115
# Ccne2
# Mms22l
# Map3k7
# Casp8ap2
# Mob3b
# Chmp5
# Vcp
# Nans
# Alg2
# Nipsnap3b
# Pole3
# Cmpk1
# Nasp
# Med8
# Ppih
# Ctps
# Rnf168
# Tagln3
# Chaf1b
# Brwd1
# Dynlt1a
# Dynlt1f
# Ezr
# Mrpl18
# Acat2
# Wtap
# Kctd5
# Ppil1
# Mtch1
# Bag6
# Tcf19
# Mrpl14
# Chaf1a
# Uhrf1
# Ptprs
# Khsrp
# Spast
# Hnrnpll
# Srsf7
# Ss18
# Slc39a6
# Tpgs2
# Polr2d
# Ube2d2a
# Ap3s1
# Csnk1g3
# Pard6g
# Mrpl49
# Polr2g
# Fen1
# Smc5
# Hells
# Actr1a
# Brca1
# Slc32a1
# Rrm2
# Insm1
# Akt1
# Trp53
# Mcm2
# Pcna
#
# DOWN:

# %%
cutoff = 0.1


# UP
enr_up = gp.enrichr(gene_list=list(sig_genes_up),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             #outdir=f"results/for_imputation/pathway_enrichment/SvW_NSC_up",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_up.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=10,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()

# DOWN
enr_down = gp.enrichr(gene_list=list(sig_genes_down),
             gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
             background=[x.capitalize() for x in df.index.values],
             organism="mouse",
             #outdir=f"results/for_imputation/pathway_enrichment/SvW_NSC_down",
             verbose=True,
             cutoff=cutoff)

ax = gp.dotplot(enr_down.results,
          column="Adjusted P-value",
          x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
          size=10,
          top_term=10,
          figsize=(3,5),
          xticklabels_rot=45, # rotate xtick labels
          marker='o',
          cutoff = cutoff
         )
plt.show()
# Out:
# 2023-11-07 15:27:09,606 [INFO] Run: GO_Biological_Process_2023
# 2023-11-07 15:27:11,319 [INFO] Done.
# 2023-11-07 15:27:12,251 [INFO] Run: GO_Biological_Process_2023
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[16], line 26
#      23 plt.show()
#      25 # DOWN
# ---> 26 enr_down = gp.enrichr(gene_list=list(sig_genes_down),
#      27              gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
#      28              background=[x.capitalize() for x in df.index.values],
#      29              organism="mouse",
#      30              #outdir=f"results/for_imputation/pathway_enrichment/SvW_NSC_down",
#      31              verbose=True,
#      32              cutoff=cutoff)
#      34 ax = gp.dotplot(enr_down.results,
#      35           column="Adjusted P-value",
#      36           x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
#    (...)
#      42           cutoff = cutoff
#      43          )
#      44 plt.show()
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/__init__.py:510, in enrichr(gene_list, gene_sets, organism, outdir, background, cutoff, format, figsize, top_term, no_plot, verbose)
#     508 # set organism
#     509 enr.set_organism()
# --> 510 enr.run()
#     512 return enr
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:506, in Enrichr.run(self)
#     504     self._logger.debug("Enrichr service using library: %s" % (self._gs))
#     505     # self._logger.info("Enrichr Library: %s"% self._gs)
# --> 506     shortID, res = self.get_results(genes_list)
#     507     # Remember gene set library used
#     508 res.insert(0, "Gene_set", self._gs)
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:230, in Enrichr.get_results(self, gene_list)
#     228 """Enrichr API"""
#     229 ADDLIST_URL = "%s/%s/addList" % (self.ENRICHR_URL, self._organism)
# --> 230 job_id = self.send_genes(gene_list, ADDLIST_URL)
#     231 user_list_id = job_id["userListId"]
#     233 RESULTS_URL = "%s/%s/export" % (self.ENRICHR_URL, self._organism)
#
# File ~/.conda/envs/merfish/lib/python3.10/site-packages/gseapy/enrichr.py:205, in Enrichr.send_genes(self, gene_list, url)
#     203     self._logger.debug(url)
#     204     self._logger.debug(payload)
# --> 205     raise Exception("Error sending gene list, try again later")
#     206 job_id = json.loads(response.text)
#     208 return job_id
#
# Exception: Error sending gene list, try again later

# %%
# concat results
enr_up.res2d['UP_DW'] = "UP"

enr_up_new = enr_up
enr_up_new.results["Term"] = [v.split("(GO:")[0] for v in enr_up_new.results["Term"].values]

ax = gp.barplot(enr_up_new.results,
                top_term=5,
                cutoff=0.05,
                title='GO BP',
                figsize=(1.5,4),
                color='cornflowerblue')
plt.tight_layout()
plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_SvW_NSC_up.pdf",
           bbox_inches='tight')
plt.show()
# Out:
# /local/scratch/edsun/slrmtmp.42103730/ipykernel_4567/2661714791.py:13: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # Near vs Far (conditioned on cell types)
#
# Near vs Far target cells with respect to effector cells -- separated by different cell types

# %% [markdown]
# ### T cell

# %%
# read in results

adata = large_load("results/for_imputation/SCPI_k4_k1/SVZ_spage_tangram_MI_EXTERNAL_TTEST_proximity to T cell_Near_marginalizedOncelltype",
                   skipfiles=["tangram_predicted_expression.csv",
                              "tangram_predicted_expression_groups.csv",
                              "tangram_predicted_expression_uncertainty.csv",
                              "spage_predicted_expression.csv",
                              "spage_predicted_expression_groups.csv",
                              "spage_predicted_expression_uncertainty.csv",
                              "knn_predicted_expression.csv",
                              "knn_predicted_expression_groups.csv",
                              "knn_predicted_expression_uncertainty.csv",])

# %%
adata.uns[f"tangram_NearAstrocyte_FarAstrocyte_varb"]
# Out:
#    xkr4  sox17  mrpl15  lypla1  tcea1  rgs20  atp6v1h  rb1cc1  4732440d04rik  \
# 0   NaN    NaN     NaN     NaN    NaN    NaN      NaN     NaN            NaN
#
#    st18  ...  pbx3  slc2a4  stat1  pcna  spock2  gfap  apln  casp2  lsamp  ntm
# 0   NaN  ...   NaN     NaN    NaN   NaN     NaN   NaN   NaN    NaN    NaN  NaN
#
# [1 rows x 12719 columns]

# %%
np.unique(adata.obs["marginal_condition"], return_counts=True)
# Out:
# (array(['FarAstrocyte', 'FarEndothelial', 'FarEpendymal', 'FarMacrophage',
#         'FarMicroglia', 'FarNSC', 'FarNeuroblast', 'FarNeuron-Excitatory',
#         'FarNeuron-MSN', 'FarOPC', 'FarOligodendrocyte', 'FarPericyte',
#         'FarT cell', 'FarVSMC', 'NearAstrocyte', 'NearEndothelial',
#         'NearEpendymal', 'NearMacrophage', 'NearMicroglia', 'NearNSC',
#         'NearNeuroblast', 'NearNeuron-Excitatory', 'NearNeuron-MSN',
#         'NearOPC', 'NearOligodendrocyte', 'NearPericyte', 'NearT cell',
#         'NearVSMC', 'OtherAstrocyte', 'OtherEndothelial', 'OtherEpendymal',
#         'OtherMacrophage', 'OtherMicroglia', 'OtherNSC', 'OtherNeuroblast',
#         'OtherNeuron-Excitatory', 'OtherNeuron-MSN', 'OtherOPC',
#         'OtherOligodendrocyte', 'OtherPericyte', 'OtherT cell',
#         'OtherVSMC'], dtype=object),
#  array([ 433,  342,   41,  151,  198,   14,   22,  387,  190,   44,  787,
#           73,   82,  334,  433,  342,   41,  151,  198,   14,   22,  387,
#          190,   44,  787,   73,   90,  334, 3368,  940, 3509,   42,  462,
#         2554, 3779,  124, 1054,  363, 2628,  274,  870,   51]))

# %%
celltypes = np.unique(adata.obs.celltype)

for ct in celltypes:
    
    print(ct)
    
    # get dataframe with p-values and t-statistics

    df = adata.uns[f"spage_Near{ct}_Far{ct}_pvalue"].T
    df.columns = ["SpaGE p"]
    df["Tangram p"] = adata.uns[f"tangram_Near{ct}_Far{ct}_pvalue"].T

    df["SpaGE t"] = adata.uns[f"spage_Near{ct}_Far{ct}_tstat"].T
    df["Tangram t"] = adata.uns[f"tangram_Near{ct}_Far{ct}_tstat"].T

    # get lists of DEGs

    # # p-value selection (permissive)
    rejected = (df['SpaGE p']<0.05)&(df['Tangram p']<0.05)

    # remove conflicting directions
    rejected[(np.sign(df['SpaGE t'])!=np.sign(df['Tangram t']))] = False

    # print DEGs
    print("UP:")
    sig_genes_up = df.index.values[rejected & (df['SpaGE t'].values>0)]
    sig_genes_up = [x.capitalize() for x in sig_genes_up]
    for gene in sig_genes_up:
        print(gene)

    print("\nDOWN:")
    sig_genes_down = df.index.values[rejected & (df['SpaGE t'].values<0)]
    sig_genes_down = [x.capitalize() for x in sig_genes_down]
    for gene in sig_genes_down:
        print(gene)



    # Plots
    cutoff = 0.1


    # UP
    try:
        enr_up = gp.enrichr(gene_list=list(sig_genes_up),
                     gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
                     background=[x.capitalize() for x in df.index.values],
                     organism="mouse",
                     verbose=True,
                     cutoff=cutoff)

        ax = gp.dotplot(enr_up.results,
                  column="Adjusted P-value",
                  x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
                  size=10,
                  top_term=5,
                  figsize=(3,5),
                  xticklabels_rot=45, # rotate xtick labels
                  marker='o',
                  cutoff = cutoff
                 )
        plt.show()
    except:
        pass

    # DOWN
    try:
        enr_down = gp.enrichr(gene_list=list(sig_genes_down),
                     gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
                     background=[x.capitalize() for x in df.index.values],
                     organism="mouse",
                     verbose=True,
                     cutoff=cutoff)

        ax = gp.dotplot(enr_down.results,
                  column="Adjusted P-value",
                  x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
                  size=10,
                  top_term=5,
                  figsize=(3,5),
                  xticklabels_rot=45, # rotate xtick labels
                  marker='o',
                  cutoff = cutoff
                 )
        plt.show()
    except:
        pass
    
    try:
        # concat results
        enr_up.res2d['UP_DW'] = "UP"

        enr_up_new = enr_up
        enr_up_new.results["Term"] = [v.split("(GO:")[0] for v in enr_up_new.results["Term"].values]

        ax = gp.barplot(enr_up_new.results,
                        top_term=5,
                        cutoff=0.05,
                        title='GO BP',
                        figsize=(1.5,4),
                        color='salmon')
        plt.tight_layout()
        #plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_Tcell_up.pdf",
        #           bbox_inches='tight')
        plt.show()
    except:
        pass
# Out:
# Astrocyte
# UP:
#
# DOWN:
# 2023-11-26 17:55:06,411 [INFO] Run: GO_Biological_Process_2023
# Endothelial
# UP:
#
# DOWN:
# 2023-11-26 17:55:07,356 [INFO] Run: GO_Biological_Process_2023
# Ependymal
# UP:
#
# DOWN:
# 2023-11-26 17:55:08,323 [INFO] Run: GO_Biological_Process_2023
# Macrophage
# UP:
#
# DOWN:
# 2023-11-26 17:55:09,385 [INFO] Run: GO_Biological_Process_2023
# Microglia
# UP:
#
# DOWN:
# 2023-11-26 17:55:10,234 [INFO] Run: GO_Biological_Process_2023
# NSC
# UP:
#
# DOWN:
# 2023-11-26 17:55:11,388 [INFO] Run: GO_Biological_Process_2023
# Neuroblast
# UP:
#
# DOWN:
# 2023-11-26 17:55:12,235 [INFO] Run: GO_Biological_Process_2023
# Neuron-Excitatory
# UP:
#
# DOWN:
# 2023-11-26 17:55:13,183 [INFO] Run: GO_Biological_Process_2023
# Neuron-MSN
# UP:
#
# DOWN:
# 2023-11-26 17:55:14,075 [INFO] Run: GO_Biological_Process_2023
# OPC
# UP:
#
# DOWN:
# 2023-11-26 17:55:15,028 [INFO] Run: GO_Biological_Process_2023
# Oligodendrocyte
# UP:
#
# DOWN:
# 2023-11-26 17:55:15,951 [INFO] Run: GO_Biological_Process_2023
# Pericyte
# UP:
#
# DOWN:
# 2023-11-26 17:55:17,005 [INFO] Run: GO_Biological_Process_2023
# T cell
# UP:
#
# DOWN:
# 2023-11-26 17:55:17,980 [INFO] Run: GO_Biological_Process_2023
# VSMC
# UP:
#
# DOWN:
# 2023-11-26 17:55:19,044 [INFO] Run: GO_Biological_Process_2023

# %% [markdown]
# ### NSC

# %% [markdown]
# # NearStrong vs NearWeak
#
# Target cells that are near strong effector cells compared to target cells that are near weaker effector cells

# %% [markdown]
# ### T cell

# %%
adata = large_load("results/for_imputation/SCPI_k4_k1/SVZ_finegrainedNear_spage_tangram_MI_EXTERNAL_TTEST_finegrained proximity to T cell_NearS",
                   skipfiles=["tangram_predicted_expression.csv",
                              "tangram_predicted_expression_groups.csv",
                              "tangram_predicted_expression_uncertainty.csv",
                              "spage_predicted_expression.csv",
                              "spage_predicted_expression_groups.csv",
                              "spage_predicted_expression_uncertainty.csv",
                              "knn_predicted_expression.csv",
                              "knn_predicted_expression_groups.csv",
                              "knn_predicted_expression_uncertainty.csv",])

# %%
# get dataframe with p-values and t-statistics

df = adata.uns[f"spage_NearS_NearW_pvalue"].T
df.columns = ["SpaGE p"]
df["Tangram p"] = adata.uns[f"tangram_NearS_NearW_pvalue"].T

df["SpaGE t"] = adata.uns[f"spage_NearS_NearW_tstat"].T
df["Tangram t"] = adata.uns[f"tangram_NearS_NearW_tstat"].T

# get lists of DEGs

# # p-value selection (permissive)
rejected = (df['SpaGE p']<0.05)&(df['Tangram p']<0.05)

# remove conflicting directions
rejected[(np.sign(df['SpaGE t'])!=np.sign(df['Tangram t']))] = False

# print DEGs
print("UP:")
sig_genes_up = df.index.values[rejected & (df['SpaGE t'].values>0)]
sig_genes_up = [x.capitalize() for x in sig_genes_up]
# for gene in sig_genes_up:
#     print(gene)

print("\nDOWN:")
sig_genes_down = df.index.values[rejected & (df['SpaGE t'].values<0)]
sig_genes_down = [x.capitalize() for x in sig_genes_down]
# for gene in sig_genes_down:
#     print(gene)



# Plots
cutoff = 0.1


# UP
try:
    enr_up = gp.enrichr(gene_list=list(sig_genes_up),
                 gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
                 background=[x.capitalize() for x in df.index.values],
                 organism="mouse",
                 verbose=True,
                 cutoff=cutoff)

    ax = gp.dotplot(enr_up.results,
              column="Adjusted P-value",
              x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
              size=10,
              top_term=5,
              figsize=(3,5),
              xticklabels_rot=45, # rotate xtick labels
              marker='o',
              cutoff = cutoff
             )
    plt.show()
except:
    pass

# DOWN
try:
    enr_down = gp.enrichr(gene_list=list(sig_genes_down),
                 gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
                 background=[x.capitalize() for x in df.index.values],
                 organism="mouse",
                 verbose=True,
                 cutoff=cutoff)

    ax = gp.dotplot(enr_down.results,
              column="Adjusted P-value",
              x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
              size=10,
              top_term=5,
              figsize=(3,5),
              xticklabels_rot=45, # rotate xtick labels
              marker='o',
              cutoff = cutoff
             )
    plt.show()
except:
    pass

try:
    # concat results
    enr_up.res2d['UP_DW'] = "UP"

    enr_up_new = enr_up
    enr_up_new.results["Term"] = [v.split("(GO:")[0] for v in enr_up_new.results["Term"].values]

    ax = gp.barplot(enr_up_new.results,
                    top_term=5,
                    cutoff=0.05,
                    title='GO BP',
                    figsize=(1.5,4),
                    color='salmon')
    plt.tight_layout()
    #plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_Tcell_up.pdf",
    #           bbox_inches='tight')
    plt.show()
except:
    pass


try:
    # concat results
    enr_down.res2d['UP_DW'] = "DOWN"

    enr_down_new = enr_down
    enr_down_new.results["Term"] = [v.split("(GO:")[0] for v in enr_down_new.results["Term"].values]

    ax = gp.barplot(enr_down_new.results,
                    top_term=5,
                    cutoff=0.05,
                    title='GO BP',
                    figsize=(1.5,4),
                    color='cornflowerblue')
    plt.tight_layout()
    #plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_Tcell_up.pdf",
    #           bbox_inches='tight')
    plt.show()
except:
    pass
# Out:
# UP:
# St18
# Sgk3
# Jph1
# Paqr8
# Tmem14a
# Lmbrd1
# Ptp4a1
# Dst
# Tmeff2
# Mfsd6
# Hecw2
# Plcl1
# Tmem237
# Cyp20a1
# Acadl
# Aamp
# Pnkd
# Tmbim1
# Retreg2
# Dnajb2
# Dock10
# Fbxo36
# Efhd1
# Agap1
# Rnpepl1
# Kif1a
# Fam174a
# D1ertd622e
# Phlpp1
# Kdsr
# Cdh19
# Dbi
# Dars
# Cdk18
# Tmcc2
# Dstyk
# Slc38a11
# Gm13889
# Myl9
# Tpm2
# Gja4
# Nbl1
# Rasl11a
# Gm13861
# Nr2f2
# Perp
# Ndufa4l2
# Mustn1
# Tagln
# Aspn
# Myh11
# Mylk
# 2023-11-26 18:07:57,208 [INFO] Run: GO_Biological_Process_2023
# 2023-11-26 18:08:01,319 [INFO] Done.
# 2023-11-26 18:08:02,154 [INFO] Run: GO_Biological_Process_2023
# 2023-11-26 18:08:03,046 [INFO] Done.
# /local/scratch/edsun/slrmtmp.42177532/ipykernel_27126/47938942.py:96: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# /local/scratch/edsun/slrmtmp.42177532/ipykernel_27126/47938942.py:117: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### NSC

# %%
adata = large_load("results/for_imputation/SCPI_k4_k1/SVZ_finegrainedNear_spage_tangram_MI_EXTERNAL_TTEST_finegrained proximity to NSC_NearS",
                   skipfiles=["tangram_predicted_expression.csv",
                              "tangram_predicted_expression_groups.csv",
                              "tangram_predicted_expression_uncertainty.csv",
                              "spage_predicted_expression.csv",
                              "spage_predicted_expression_groups.csv",
                              "spage_predicted_expression_uncertainty.csv",
                              "knn_predicted_expression.csv",
                              "knn_predicted_expression_groups.csv",
                              "knn_predicted_expression_uncertainty.csv",])

# %%
# get dataframe with p-values and t-statistics

df = adata.uns[f"spage_NearS_NearW_pvalue"].T
df.columns = ["SpaGE p"]
df["Tangram p"] = adata.uns[f"tangram_NearS_NearW_pvalue"].T

df["SpaGE t"] = adata.uns[f"spage_NearS_NearW_tstat"].T
df["Tangram t"] = adata.uns[f"tangram_NearS_NearW_tstat"].T

# get lists of DEGs

# # p-value selection (permissive)
rejected = (df['SpaGE p']<0.05)&(df['Tangram p']<0.05)

# remove conflicting directions
rejected[(np.sign(df['SpaGE t'])!=np.sign(df['Tangram t']))] = False

# print DEGs
print("UP:")
sig_genes_up = df.index.values[rejected & (df['SpaGE t'].values>0)]
sig_genes_up = [x.capitalize() for x in sig_genes_up]
# for gene in sig_genes_up:
#     print(gene)

print("\nDOWN:")
sig_genes_down = df.index.values[rejected & (df['SpaGE t'].values<0)]
sig_genes_down = [x.capitalize() for x in sig_genes_down]
# for gene in sig_genes_down:
#     print(gene)



# Plots
cutoff = 0.1


# UP
try:
    enr_up = gp.enrichr(gene_list=list(sig_genes_up),
                 gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
                 background=[x.capitalize() for x in df.index.values],
                 organism="mouse",
                 verbose=True,
                 cutoff=cutoff)

    ax = gp.dotplot(enr_up.results,
              column="Adjusted P-value",
              x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
              size=10,
              top_term=5,
              figsize=(3,5),
              xticklabels_rot=45, # rotate xtick labels
              marker='o',
              cutoff = cutoff
             )
    plt.show()
except:
    pass

# DOWN
try:
    enr_down = gp.enrichr(gene_list=list(sig_genes_down),
                 gene_sets=["GO_Biological_Process_2023"],#, "KEGG_2019_Mouse", "Reactome_2022"],
                 background=[x.capitalize() for x in df.index.values],
                 organism="mouse",
                 verbose=True,
                 cutoff=cutoff)

    ax = gp.dotplot(enr_down.results,
              column="Adjusted P-value",
              x='Gene_set', # set x axis, so you could do a multi-sample/library comparsion
              size=10,
              top_term=5,
              figsize=(3,5),
              xticklabels_rot=45, # rotate xtick labels
              marker='o',
              cutoff = cutoff
             )
    plt.show()
except:
    pass

try:
    # concat results
    enr_up.res2d['UP_DW'] = "UP"

    enr_up_new = enr_up
    enr_up_new.results["Term"] = [v.split("(GO:")[0] for v in enr_up_new.results["Term"].values]

    ax = gp.barplot(enr_up_new.results,
                    top_term=5,
                    cutoff=0.05,
                    title='GO BP',
                    figsize=(1.5,4),
                    color='salmon')
    plt.tight_layout()
    #plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_Tcell_up.pdf",
    #           bbox_inches='tight')
    plt.show()
except:
    pass


try:
    # concat results
    enr_down.res2d['UP_DW'] = "DOWN"

    enr_down_new = enr_down
    enr_down_new.results["Term"] = [v.split("(GO:")[0] for v in enr_down_new.results["Term"].values]

    ax = gp.barplot(enr_down_new.results,
                    top_term=5,
                    cutoff=0.05,
                    title='GO BP',
                    figsize=(1.5,4),
                    color='cornflowerblue')
    plt.tight_layout()
    #plt.savefig(f"plots/mechanism/unbiased_GOPBP_enrichment_NvF_Tcell_up.pdf",
    #           bbox_inches='tight')
    plt.show()
except:
    pass
# Out:
# UP:
# St18
# Pcmtd1
# Sgk3
# Jph1
# Tmem14a
# Smap1
# Lmbrd1
# Ptp4a1
# Dst
# Unc50
# Tmeff2
# Gm28322
# Mfsd6
# Hecw2
# Plcl1
# 1700066m21rik
# Cyp20a1
# Pnkd
# Tmbim1
# Retreg2
# Dnajb2
# Ptprn
# Dock10
# Mff
# Agfg1
# Cab39
# Psmd1
# Efhd1
# Agap1
# Kif1a
# Ppp1r7
# Hdlbp
# Fam174a
# D1ertd622e
# Cdh20
# Phlpp1
# Tmem163
# R3hdm1
# Nucks1
# Cdk18
# Tmcc2
# Dstyk
# Cntn2
# Nfasc
# Pik3c2b
# Ppp1r15b
# Adora1
# Adipor1
# Arl8a
# Timm17a
# Shisa4
# Csrp1
# Phlda3
# Tnni1
# Zfp281
# Glul
# Stx6
# Cep350
# Rasal2
# Rabgap1l
# Dnm3
# Pogk
# Ndufs2
# Adamts4
# Pea15a
# Igsf8
# Kcnj10
# Sccpdh
# Cdc42bpa
# Pycr2
# Tmem63a
# Degs1
# 1700047m11rik
# Trp53bp2
# Dusp10
# Bpnt1
# Eprs
# Kctd3
# Prox1os
# Ppp2r5a
# Lpgat1
# Rcor3
# Prkcq
# Gm13293
# Rsu1
# Hacd1
# Stam
# Pip4k2a
# Nsmf
# Rnf208
# Tprn
# Abca2
# Ptgds
# Edf1
# Tmem141
# Nacc2
# Sdccag3
# Ralgds
# Urm1
# Zer1
# Sh3glb2
# Ptpa
# Fnbp1
# Abl1
# Fam102a
# Lrp1b
# Tnfaip6
# Rif1
# Stam2
# Fmnl2
# Ermn
# Pkp4
# Tanc1
# Gca
# Fign
# Grb14
# Cobll1
# B3galt1
# Stk39
# Ubr3
# Dcaf17
# Gpr155
# Wipf1
# Nckap1
# Itgav
# Fam171b
# Pacsin3
# Mapk8ip1
# Cd82
# Lrrc4c
# Prr5l
# Depdc7
